# %% [markdown]
# # Final Project Information
#
# - No project is considered too small. **The primary objective of the final project is to familiarize you with the process of developing a machine learning model.** While the use of Neural Networks is encouraged for your projects, it is not mandatory. Your neural network model does not need to be highly complex, especially if there are constraints on training resources. Although our class has concentrated on computer vision topics such as image classification, object detection, and image generation, you are welcome to explore other areas, including natural language processing (e.g., machine translation) and time series data prediction (e.g., weather forecasting, stock market prediction).
#
# - The project report accounts for 95 points, with a dedicated section for contributions worth 15 points. Undergraduate students automatically receive these 15 points for their contributions. However, to earn these points, graduate students must demonstrate unique contributions. Additionally, there are 5 points available for the project presentation, with the opportunity to earn 10 extra points.
#
# - Please ensure that all your code is submitted and that this notebook can be executed without any errors. Failure to do so will result in receiving no points for the code sections. It is advisable to download your submission and re-run the code sections in the notebook yourself to verify their correctness.
#
# **Please complete the project template provided below. Remove all Italian text from the section. They serve only as instructions for what needs to be written.**

# %% [markdown]
# # Project Title

# %% [markdown]
# ## Team members
# - _**uniqueName, firstName lastName, UMID**_
# - _**uniqueName, firstName lastName, UMID**_

# %% [markdown]
# ## Introduction (2 pts)

# %% [markdown]
# _**Clearly define the problem that your project aims to solve. Explain why this problem is important to solve and the potential benefits of solving it. (Classifying an image as a hotdog or not could potentially have its usefulness, especially for fans of 'Silicon Valley :)) (2 pts)**_

# %% [markdown]
# ## Dataset Description (5 pts)

# %% [markdown]
# _**Begin with a brief introduction to the dataset and why do you use it. Include information on what the dataset comprises, its size (e.g., number of images, records, or files), and what each data point represents. If your project utilizes multiple datasets, describe each one separately under subheadings. (1 pts)**_
#
# _**Detail the origin of your dataset. Address the following points as applicable: 1) Public or Private: Specify whether the dataset is publicly available or sourced from a private collection. If public, mention the platform or repository from which it was obtained. 2) Ownership: If the dataset was created or collected by an organization, research group, or individual, acknowledge them here. (1 pts)**_

# %% [markdown]
# ### Code Section for Loading the Dataset (3 pts)

# %%
# Loading the dataset

# %% [markdown]
# ## Model Description (15 pts)

# %% [markdown]
# _**Begin with a brief introduction to the chosen model or architecture. Explain why this model was selected for your project. This should include: 1) Type of Model: Clearly state whether it is a Fully-Connected Neural Networ(MLP), Convolutional Neural Network (CNN), Recurrent Neural Network (RNN), Transformer, or any other architecture. If it's a combination of types, explain how they are integrated. 2) Number of Layers: Specify the total number of layers in your model. Break down the model structure, layer by layer, if possible. Layer Details: For each layer, describe its type (e.g., convolutional, pooling, fully connected, normalization, dropout). (4 pts)**_
#
# _**Discuss the model's complexity by providing an overview of the number of parameters (A rough number is Okay. Just make sure you understand the complexity). (1 pts)**_

# %% [markdown]
# ### Code Section for Loading Project Model (10 pts)

# %%
# Loading the model

# %% [markdown]
# ## Model Training and Validation Description and Experiments (55 pts)

# %% [markdown]
# _**This section should outline the processes and methodologies employed in training and validating your deep learning model. It is important to provide clear and detailed explanations of the loss function, and data division of your project's experimental setup.**_
#
# _**You should outline the optimization algorithm selected for the training process, such as Adam, SGD, or RMSprop, and explain the reasoning behind its choice. Additionally, detail the chosen batch size for training, including the considerations that influenced this decision. Specify the initial learning rate, along with any modifications applied during the training phase, like learning rate schedules or decay mechanisms. Describe the criteria or conditions under which training was concluded. (5 pts)**_
#
# _**You need to specify which loss functions were employed and explain the rationale behind their selection. (5 pts)**_
#
# _**You also need to detail the method used to divide the dataset, including the splitting ratio, whether the data was shuffled, and other relevant considerations if applied. (5 pts)**_
#
# _**However, if your project involves utilizing an open-source model without conducting any training yourself, please include a description of the training methodology, dataset and loss functions as detailed by the original authors.**_
#
# _**Explain the metrics used to evaluate model performance, such as accuracy, precision, recall, F1 score, and any domain-specific metrics. Justify the choice of these metrics based on the goals of your project. Outline the measures implemented to enhance and refine the performance of the model, if applicable. (3 pts)**_
#
# _**Discuss the outcomes of your experiments and share insights gained from conducting these trials.. (2 pts)**_

# %% [markdown]
# ### Code Section for Performing Training (if applicable) and Evaluation and Plot Generations (25 pts)

# %%
# Code for performing training and evaluation

# %% [markdown]
# ## Conclusion (3 pts)

# %% [markdown]
# _**Begin by summarizing the primary objectives of your project and stating whether these goals were met. (1 pts)**_
#
# _**Reflect on the broader learnings and insights gained from undertaking this project, emphasizing how it has contributed to your understanding of deep learning and its applications (2 pts)**_

# %% [markdown]
# ## Contributions (15 pts)

# %% [markdown]
# _**Please enumerate your distinct contributions to this project. Up to 15 points can be awarded for this section based on the uniqueness and significance of your contributions.**_
#
# * _Submission to a conference or journal earns an additional 10 points._
# * _Participation in Kaggle competitions is rewarded with 5 to 10 points, depending on the impact._
# * _Demonstrating improvements over existing state-of-the-art methods can merit 1 to 10 points._
# * _Creating and utilizing a self-collected dataset that contributes significantly to a specific field may receive 1 to 10 points._
# * _Contributions to an open-source project are valued at 10 points._
# * _The application's novelty and interest level can lead to a score of 1 to 10 points._
# * _Code quality and effort, including well-written and substantial coding efforts, are eligible for 1 to 10 points._
# * _Evaluation quality, encompassing comprehensive, insightful analyses and remarkable findings, can earn 1 to 10 points._
# * _**Detail any aspects of your project you believe are distinctive, and specify the points you think should be awarded for these unique features.**_
